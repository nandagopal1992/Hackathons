# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cross_validation import cross_val_score
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression

import xgboost
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder

from imblearn.over_sampling import SMOTE

# %%
train = pd.read_csv('./criminal_train.csv')
test = pd.read_csv('./criminal_test.csv')

# %%
train.head()
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  25095143        4         2         4         1         3         1
# 1  13005143        4         1         3         1         2         1
# 2  67415143        4         1         2         1         2         1
# 3  70925143        4         0         2         1         1         1
# 4  75235143        1         0         6         1         4         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY    ...     TOOLONG  TROUBUND  PDEN10  COUTYP2  \
# 0         1         1        99    ...           1         2       1        1
# 1         1         1        99    ...           2         2       2        3
# 2         1         1        99    ...           2         2       2        3
# 3         1         1        99    ...           2         2       1        1
# 4         1         1        99    ...           2         2       2        2
#
#    MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP  Criminal
# 0         2         2  3884.805998  40026      1         0
# 1         2         2  1627.108106  40015      2         1
# 2         2         2  4344.957980  40024      1         0
# 3         2         2   792.521931  40027      1         0
# 4         2         2  1518.118526  40001      2         0
#
# [5 rows x 72 columns]

# %%
train.Criminal.value_counts()
# Out:
# 0    42543
# 1     3175
# Name: Criminal, dtype: int64

# %%
train.ANALWT_C.median()
# Out:
# 2719.3351599999996

# %%
drop_list = ['PERID']

# %%
ANALWT_C_train = train['ANALWT_C']
train = train.drop(['ANALWT_C'] , axis=1)

# %%
ANALWT_C_test = test['ANALWT_C']
test = test.drop(['ANALWT_C'] , axis=1)

# %%
train = train.drop(drop_list , axis=1)
test = test.drop(drop_list , axis=1)

# %%
le = LabelEncoder()
for col in train.columns:
    if col != 'Criminal':
        data=train[[col]].append(test[[col]])
        le.fit(data);
        train[col] = le.transform(train[col])
        test[col] = le.transform(test[col])

# %%
from sklearn.preprocessing import OneHotEncoder
enc=OneHotEncoder(sparse=False)
for col in train.columns:
    if col != 'Criminal':
        data=train[[col]].append(test[[col]])
        enc.fit(data)
        # Fitting One Hot Encoding on train data
        temp = enc.transform(train[[col]])
        # Changing the encoded features into a data frame with new column names
        temp=pd.DataFrame(temp,columns=[(col+"_"+str(i)) for i in data[col]
                .value_counts().index])
        # In side by side concatenation index values should be same
        # Setting the index values similar to the X_train data frame
        temp=temp.set_index(train.index.values)
        # adding the new One Hot Encoded varibales to the train data frame
        train=pd.concat([train,temp],axis=1)
        # fitting One Hot Encoding on test data
        temp = enc.transform(test[[col]])
        # changing it into data frame and adding column names
        temp=pd.DataFrame(temp,columns=[(col+"_"+str(i)) for i in data[col]
                .value_counts().index])
        # Setting the index for proper concatenation
        temp=temp.set_index(test.index.values)
        # adding the new One Hot Encoded varibales to test data frame
        test=pd.concat([test,temp],axis=1)

# %%
y_train = train['Criminal']
train = train.drop( ['Criminal'] , axis=1)

# %%
train['ANALWT_C'] = ANALWT_C_train
test['ANALWT_C'] = ANALWT_C_test

# %%
print train.shape
print test.shape
print y_train.shape
# Out:
# (45718, 471)
# (11430, 471)
# (45718,)

# %%
from sklearn.cluster import KMeans
cluster = KMeans(n_clusters = 2)
train['predicted_cluster'] = cluster.fit_predict(train)
test['predicted_cluster'] = cluster.predict(test)

# %%
sm= SMOTE(random_state=42)
X_new , Y_new = sm.fit_sample(train , y_train )

# %%
y = cluster.fit_predict(X_new)

# %%
np.bincount(y)
# Out:
# array([72798, 12288])

# %%
print np.bincount(yp)
print np.bincount(y_train)
# Out:
# [39838  5880]
# [42543  3175]

# %%
precision_score(yp , y_train)
# Out:
# 0.16881889763779528

# %%
print X_new.shape
print Y_new.shape
# Out:
# (85086, 472)
# (85086,)

# %%
class Ensemble(object):
    def __init__(self, n_splits, stacker, base_models):
        self.n_splits = n_splits
        self.stacker = stacker
        self.base_models = base_models

    def fit_predict(self, X, y, T):
        X = np.array(X)
        y = np.array(y)
        T = np.array(T)

        folds = list(StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=2016).split(X, y))

        S_train = np.zeros((X.shape[0], len(self.base_models)))
        S_test = np.zeros((T.shape[0], len(self.base_models)))
        for i, clf in enumerate(self.base_models):

            S_test_i = np.zeros((T.shape[0], self.n_splits))

            for j, (train_idx, test_idx) in enumerate(folds):
                X_train = X[train_idx]
                y_train = y[train_idx]
                X_holdout = X[test_idx]

                print ("Fit %s fold %d" % (str(clf).split('(')[0], j+1))
                clf.fit(X_train, y_train)
                y_pred = clf.predict_proba(X_holdout)[:,1]                

                S_train[test_idx, i] = y_pred
                S_test_i[:, j] = clf.predict_proba(T)[:,1]
            S_test[:, i] = S_test_i.mean(axis=1)

        results = cross_val_score(self.stacker, S_train, y, cv=3)
        print("Stacker score: %.5f" % (results.mean()))

        self.stacker.fit(S_train, y)
        res = self.stacker.predict_proba(S_test)[:,1]
        return self.stacker, res , S_train , S_test

# %%
lgb_params = {}
lgb_params['learning_rate'] = 0.02
lgb_params['n_estimators'] = 650
lgb_params['max_bin'] = 10
lgb_params['subsample'] = 0.8
lgb_params['subsample_freq'] = 10
lgb_params['colsample_bytree'] = 0.8   
lgb_params['min_child_samples'] = 500
lgb_params['feature_fraction'] = 0.9
lgb_params['bagging_freq'] = 1
lgb_params['seed'] = 200

lgb_params2 = {}
lgb_params2['n_estimators'] = 1090
lgb_params2['learning_rate'] = 0.02
lgb_params2['colsample_bytree'] = 0.3   
lgb_params2['subsample'] = 0.7
lgb_params2['subsample_freq'] = 2
lgb_params2['num_leaves'] = 16

lgb_params2['feature_fraction'] = 0.9
lgb_params2['bagging_freq'] = 1
lgb_params2['seed'] = 200


lgb_params3 = {}
lgb_params3['n_estimators'] = 1100
lgb_params3['max_depth'] = 4
lgb_params3['learning_rate'] = 0.02
lgb_params3['feature_fraction'] = 0.9
lgb_params3['bagging_freq'] = 1
lgb_params3['seed'] = 200


xgb_params = {}
xgb_params['n_estimators'] = 1000
xgb_params['max_depth'] = 4
xgb_params['learning_rate'] = 0.02

# %%
lgb_model = LGBMClassifier(**lgb_params)

lgb_model2 = LGBMClassifier(**lgb_params2)

lgb_model3 = LGBMClassifier(**lgb_params3)

xgbmodel = xgboost.XGBClassifier(**xgb_params)

# %%
log_model = LogisticRegression()      
stack = Ensemble(n_splits=5,
        stacker = log_model,
        base_models = (lgb_model, lgb_model2, lgb_model3))        
        
model ,y_pred , S_train , S_test = stack.fit_predict(X_new, Y_new, test)
# Out:
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Stacker score: 0.96098

# %%
y_pred = model.predict(S_train)
precision_score(y_pred, Y_new)
# Out:
# 0.97155818818607054

# %%
from sklearn.ensemble import RandomForestClassifier

lr = RandomForestClassifier()
lr.fit(S_train , Y_new)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_lr = lr.predict(S_train)

# %%
precision_score(y_pred, Y_new)
#0.97195778388924148
# Out:
# 0.97155818818607054

# %%
wrong_indixes = (np.where(y_pred != Y_new))
len(wrong_indixes[0])
# Out:
# 2147

# %%
Y_filterd = Y_new[wrong_indixes[0]]
len(Y_filterd)

# %%
S_train_filtered = S_train[wrong_indixes[0]]
len(S_train_filtered)
# Out:
# 2147

# %%
rf = RandomForestClassifier()
rf.fit(S_train_filtered , Y_filterd)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
len(y_pred_2)
# Out:
# 85086

# %%
y_pred4 = model2.predict(S_train_2)
precision_score(y_pred4 , Y_filterd)
# Out:
# 0.99161777032690701

# %%
log_model = LogisticRegression()      
stack = Ensemble(n_splits=5,
        stacker = log_model,
        base_models = (lgb_model, lgb_model2, lgb_model3))        
        
model2 ,y_pred_2 , S_train_2 , S_test_2 = stack.fit_predict(S_train_filtered, Y_filterd, S_test)
# Out:
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Stacker score: 0.99068

# %%
len(S_test_2)
# Out:
# 11430

# %%
y_pred3 = model2.predict(S_train)
precision_score(y_pred3 , Y_new)
# Out:
# 0.97219284018522434

# %%
y1= model2.predict(S_test_2)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y2 = model.predict(S_test)
len(y2)
# Out:
# 11430

# %%
print np.bincount(y1)
print np.bincount(y2)
# Out:
# [  743 10687]
# [10688   742]

# %%
test = pd.read_csv('./criminal_test.csv')
test['Criminal'] = lr.predict(S_test)

# %%
test[['PERID' , 'Criminal']].to_csv('./result.csv' , index= False)

# %%
# 97.2 precision score
#  accuracy score

# %%
test.Criminal.value_counts()
# Out:
# 0    10688
# 1      742
# Name: Criminal, dtype: int64

# %%
np.bincount(Y_new)
# Out:
# array([42543, 42543])

# %%
np.bincount(y_pred)
# Out:
# array([42974, 42112])

# %%
742.0/10688
# Out:
# 0.06942365269461077

# %%
import xgboost

# %%
xbb = xgboost.XGBClassifier( n_estimators=500)

# %%
xbb.fit(S_train , Y_new)
# Out:
# XGBClassifier(base_score=0.5, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, n_estimators=500,
#        nthread=-1, objective='binary:logistic', seed=0, silent=True,
#        subsample=1)

# %%
y_pred = xbb.predict(S_train)

# %%
precision_score(y_pred, Y_new)
#0.97195778388924148
# Out:
# 0.97075899677972877

# %%
# Out:
#             0         1         2    3         4    5         6    7    8    \
# 0      4.000000  3.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 1      4.000000  2.000000  3.000000  1.0  2.000000  1.0  1.000000  1.0  5.0
# 2      4.000000  2.000000  2.000000  1.0  2.000000  1.0  1.000000  1.0  5.0
# 3      4.000000  1.000000  2.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 4      1.000000  1.000000  6.000000  1.0  4.000000  1.0  1.000000  1.0  5.0
# 5      4.000000  1.000000  2.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 6      4.000000  4.000000  6.000000  1.0  4.000000  1.0  1.000000  1.0  5.0
# 7      4.000000  3.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 8      4.000000  2.000000  3.000000  1.0  2.000000  1.0  1.000000  1.0  5.0
# 9      4.000000  1.000000  1.000000  1.0  1.000000  1.0  2.000000  1.0  5.0
# 10     4.000000  1.000000  1.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 11     4.000000  1.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 12     4.000000  1.000000  2.000000  1.0  1.000000  1.0  2.000000  1.0  5.0
# 13     1.000000  1.000000  3.000000  1.0  2.000000  1.0  1.000000  1.0  5.0
# 14     1.000000  1.000000  5.000000  1.0  4.000000  1.0  1.000000  1.0  5.0
# 15     4.000000  4.000000  5.000000  1.0  4.000000  1.0  1.000000  1.0  5.0
# 16     4.000000  1.000000  2.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 17     4.000000  3.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 18     4.000000  3.000000  3.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 19     1.000000  1.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 20     1.000000  1.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 21     4.000000  2.000000  3.000000  1.0  2.000000  1.0  1.000000  1.0  5.0
# 22     1.000000  1.000000  5.000000  1.0  3.000000  1.0  2.000000  1.0  5.0
# 23     4.000000  1.000000  2.000000  1.0  1.000000  1.0  3.000000  1.0  5.0
# 24     1.000000  1.000000  6.000000  1.0  4.000000  1.0  1.000000  1.0  5.0
# 25     4.000000  1.000000  4.000000  1.0  2.000000  1.0  1.000000  1.0  5.0
# 26     4.000000  1.000000  3.000000  1.0  2.000000  2.0  1.000000  3.0  5.0
# 27     4.000000  1.000000  1.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 28     4.000000  1.000000  3.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 29     1.000000  1.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# ...         ...       ...       ...  ...       ...  ...       ...  ...  ...
# 85056  1.188104  1.000000  2.811896  1.0  2.000000  1.0  1.000000  1.0  5.0
# 85057  4.000000  1.000000  2.000000  1.0  1.000000  1.0  2.688553  1.0  5.0
# 85058  4.000000  1.000000  1.952215  1.0  1.000000  1.0  1.523892  1.0  5.0
# 85059  1.946113  1.000000  3.053887  1.0  2.946113  1.0  1.000000  1.0  5.0
# 85060  2.177566  1.088783  5.733651  1.0  3.822434  1.0  1.000000  1.0  5.0
# 85061  3.309140  2.539426  4.460574  1.0  3.230287  1.0  1.000000  1.0  5.0
# 85062  3.445562  1.000000  3.000000  1.0  1.184813  1.0  1.000000  1.0  5.0
# 85063  1.786208  1.000000  3.213792  1.0  3.000000  1.0  1.000000  1.0  5.0
# 85064  4.000000  1.000000  1.000000  1.0  1.000000  1.0  2.000000  1.0  5.0
# 85065  3.668289  1.000000  2.834144  1.0  1.165856  1.0  1.834144  1.0  5.0
# 85066  4.000000  1.000000  1.000000  1.0  1.000000  1.0  2.000000  1.0  5.0
# 85067  1.526741  1.175580  4.648840  1.0  3.648840  1.0  1.000000  1.0  5.0
# 85068  4.000000  1.916516  2.374774  1.0  1.916516  1.0  1.541742  1.0  5.0
# 85069  4.000000  1.000000  2.025100  1.0  1.025100  1.0  1.000000  1.0  5.0
# 85070  4.000000  1.000000  1.267749  1.0  1.000000  1.0  1.732251  1.0  5.0
# 85071  4.000000  1.000000  1.000000  1.0  1.000000  1.0  1.065714  1.0  5.0
# 85072  1.000000  1.000000  4.000000  1.0  3.000000  1.0  1.000000  1.0  5.0
# 85073  1.725059  1.000000  2.549881  1.0  2.274941  1.0  1.000000  1.0  5.0
# 85074  3.489759  1.000000  1.170080  1.0  1.170080  1.0  1.829920  1.0  5.0
# 85075  4.000000  1.000000  2.692570  1.0  1.000000  1.0  2.692570  1.0  5.0
# 85076  4.000000  2.702100  4.702100  1.0  3.134733  1.0  1.000000  1.0  5.0
# 85077  4.000000  1.000000  2.000000  1.0  1.000000  1.0  1.000000  1.0  5.0
# 85078  1.000000  1.000000  5.770535  1.0  4.000000  1.0  1.000000  1.0  5.0
# 85079  4.000000  1.000000  1.980698  1.0  1.000000  1.0  2.490349  1.0  5.0
# 85080  3.854171  1.000000  2.097219  1.0  1.145829  1.0  1.000000  1.0  5.0
# 85081  4.000000  1.000000  1.191388  1.0  1.000000  1.0  1.000000  1.0  5.0
# 85082  4.000000  1.221099  3.221099  1.0  1.221099  1.0  1.000000  1.0  5.0
# 85083  4.000000  1.000000  2.065103  1.0  1.000000  1.0  1.065103  1.0  5.0
# 85084  2.761496  1.587165  3.825669  1.0  2.825669  1.0  1.000000  1.0  5.0
# 85085  3.411473  1.000000  1.980879  1.0  1.588527  1.0  1.803824  1.0  5.0
#
#             9        ...       461  462       463       464       465  \
# 0      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 1      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 2      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 3      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 4      1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 5      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 6      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 7      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 8      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 9      6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 10     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 11     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 12     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 13     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 14     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 15     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 16     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 17     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 18     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 19     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 20     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 21     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 22     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 23     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 24     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 25     1.000000      ...       0.0  1.0  0.000000  0.000000  0.000000
# 26     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 27     6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 28     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 29     1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# ...         ...      ...       ...  ...       ...       ...       ...
# 85056  5.059481      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85057  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85058  6.000000      ...       0.0  0.0  0.476108  0.000000  0.000000
# 85059  1.269435      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85060  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85061  4.848566      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85062  5.075936      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85063  1.000000      ...       0.0  0.0  0.000000  0.213792  0.000000
# 85064  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85065  5.170722      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85066  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85067  1.877901      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85068  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85069  5.874502      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85070  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85071  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85072  1.000000      ...       0.0  0.0  0.000000  0.808838  0.000000
# 85073  1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85074  5.149599      ...       0.0  0.0  0.829920  0.000000  0.000000
# 85075  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85076  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85077  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85078  1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85079  3.548255      ...       0.0  0.0  0.000000  0.000000  0.490349
# 85080  5.756952      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85081  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85082  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85083  6.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85084  1.000000      ...       0.0  0.0  0.000000  0.000000  0.000000
# 85085  5.019121      ...       0.0  0.0  0.803824  0.000000  0.000000
#
#            466  467       468       469           470
# 0      0.00000  0.0  1.000000  0.000000   3884.805998
# 1      0.00000  0.0  0.000000  1.000000   1627.108106
# 2      0.00000  0.0  1.000000  0.000000   4344.957980
# 3      0.00000  0.0  1.000000  0.000000    792.521931
# 4      0.00000  0.0  0.000000  1.000000   1518.118526
# 5      0.00000  0.0  0.000000  1.000000   9129.229124
# 6      0.00000  0.0  0.000000  1.000000   6561.895497
# 7      0.00000  0.0  0.000000  1.000000   3341.718873
# 8      0.00000  0.0  0.000000  1.000000   3384.147888
# 9      0.00000  0.0  1.000000  0.000000   2636.943978
# 10     0.00000  0.0  1.000000  0.000000   3026.110863
# 11     0.00000  0.0  0.000000  1.000000   4196.225953
# 12     0.00000  0.0  1.000000  0.000000  20905.427440
# 13     0.00000  0.0  0.000000  1.000000   2671.376188
# 14     0.00000  0.0  1.000000  0.000000   1430.775669
# 15     0.00000  0.0  0.000000  1.000000   1041.374975
# 16     0.00000  0.0  1.000000  0.000000   5014.378391
# 17     0.00000  0.0  1.000000  0.000000   4757.271596
# 18     0.00000  0.0  0.000000  1.000000   2784.880401
# 19     0.00000  0.0  1.000000  0.000000    330.258076
# 20     0.00000  0.0  0.000000  1.000000   2398.833215
# 21     0.00000  0.0  0.000000  1.000000   4247.334140
# 22     0.00000  0.0  0.000000  1.000000   2432.035890
# 23     0.00000  0.0  0.000000  1.000000   9429.142633
# 24     0.00000  0.0  0.000000  1.000000    791.405193
# 25     0.00000  0.0  1.000000  0.000000    751.207301
# 26     0.00000  0.0  0.000000  1.000000   3327.695904
# 27     0.00000  0.0  0.000000  1.000000   7913.574798
# 28     0.00000  0.0  1.000000  0.000000    416.917733
# 29     0.00000  0.0  0.000000  1.000000    432.992914
# ...        ...  ...       ...       ...           ...
# 85056  0.00000  0.0  1.000000  0.000000   1179.739055
# 85057  0.00000  0.0  0.000000  1.000000   9152.414262
# 85058  0.00000  0.0  1.000000  0.000000   6532.597276
# 85059  0.00000  0.0  0.946113  0.053887    483.626310
# 85060  0.00000  0.0  0.000000  1.000000   3404.611614
# 85061  0.00000  0.0  1.000000  0.000000   1906.302987
# 85062  0.00000  0.0  0.815187  0.184813    877.221540
# 85063  0.00000  0.0  1.000000  0.000000    218.402623
# 85064  0.00000  0.0  0.268474  0.731526  12846.374609
# 85065  0.00000  0.0  0.834144  0.165856   4474.849590
# 85066  0.00000  0.0  1.000000  0.000000  16437.911695
# 85067  0.00000  0.0  0.175580  0.824420   5316.902359
# 85068  0.00000  0.0  0.541742  0.458258  10914.582571
# 85069  0.00000  0.0  0.974900  0.025100    253.009549
# 85070  0.00000  0.0  0.267749  0.732251   8253.227952
# 85071  0.00000  0.0  0.065714  0.934286  23561.908869
# 85072  0.00000  0.0  1.000000  0.000000    495.224922
# 85073  0.00000  0.0  0.725059  0.274941    699.946473
# 85074  0.00000  0.0  0.829920  0.170080   5414.691998
# 85075  0.69257  0.0  1.000000  0.000000  48894.589859
# 85076  0.00000  0.0  0.432633  0.567367   4006.537461
# 85077  0.00000  0.0  1.000000  0.000000   3267.818991
# 85078  0.00000  0.0  0.229465  0.770535    176.379904
# 85079  0.00000  0.0  0.509651  0.490349   9942.318658
# 85080  0.00000  0.0  0.951390  0.048610    535.330955
# 85081  0.00000  0.0  0.000000  1.000000    401.965174
# 85082  0.00000  0.0  1.000000  0.000000   8059.388166
# 85083  0.00000  0.0  0.000000  1.000000  11270.438998
# 85084  0.00000  0.0  1.000000  0.000000   4607.394952
# 85085  0.00000  0.0  0.803824  0.196176    822.330703
#
# [85086 rows x 471 columns]

# %%
colmn = train.columns

# %%
newdf = pd.DataFrame(X_new  , columns=colmn)

# %%
newdf['Pred_Criminal'] = y_pred

# %%
newdf['Criminal']= Y_new

# %%
incorrectdf = newdf[newdf.Pred_Criminal != newdf.Criminal]
y_incorrectdf = newdf['Criminal']

# %%
incorrectdf = incorrectdf.drop(['Criminal' , 'Pred_Criminal'] , axis=1)

# %%
incorrectdf.ANALWT_C.median()
# Out:
# 2600.987919
